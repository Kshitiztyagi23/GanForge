# %% [markdown]
# Importng Libraries

# %%
import numpy as np
import matplotlib.image as mpimg
from PIL import Image
import cv2
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8efeedc1-d194-4ff7-b67c-2680694fa60e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8efeedc1-d194-4ff7-b67c-2680694fa60e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Importing the image through different methods

# %%
img = list(uploaded.keys())[0]
img_ = Image.open(img)
plt.imshow(img_)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3839.5), np.float64(2159.5), np.float64(-0.5))

# %%
img1 = cv2.imread(img)
plt.imshow(img1)
plt.axis("off")
print(img1.shape)
# Out:
# (2160, 3840, 3)

# %%
img2= img2[:,:,[2,1,0]]  #changing the BGR to RGB
plt.imshow(img2)
plt.axis("off")
print(img2.shape)
# Out:
# (2160, 3840, 3)

# %%
img2= np.array(Image.open(img))
plt.imshow(img2)
plt.axis("off")
print(img2.shape)
# Out:
# (2160, 3840, 3)

# %%
img3 = cv2.imread(img,0)
plt.imshow(img3, cmap='gray')
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3839.5), np.float64(2159.5), np.float64(-0.5))

# %%
plt.imshow(img3, cmap='plasma')
plt.axis("off")
plt.colorbar()

# %% [markdown]
# Converting BGR to RGB or to Gray by different method

# %%
img4= cv2.imread(img)
img_converted1 = cv2.cvtColor(img4, cv2.COLOR_BGR2RGB)
img_converted2 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
plt.imshow(img_converted1)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3839.5), np.float64(2159.5), np.float64(-0.5))

# %%
img_blue= np.zeros_like(img4)
img_green= np.zeros_like(img4)
img_red= np.zeros_like(img4)
img_blue[:,:,2] = img4[:,:,2]  # matplotlib expects RGB so it automatically converts BGR to RGB
img_green[:,:,1] = img4[:,:,1]
img_red[:,:,0] = img4[:,:,0]
plt.figure(figsize= (12,12))
plt.subplot(1,3,1)
plt.imshow(img_blue)
plt.title("Blue")
plt.axis("off")
plt.subplot(1,3,2)
plt.imshow(img_green)
plt.title("Green")
plt.axis("off")
plt.subplot(1,3,3)
plt.imshow(img_red)
plt.title("Red")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(3839.5), np.float64(2159.5), np.float64(-0.5))

# %% [markdown]
# Playing with image manipulation

# %%
print(img4.shape)
# Out:
# (2160, 3840, 3)

# %%
img5 = cv2.resize(img_converted1, (10000,5000))
plt.imshow(img5)
print(img5.shape)
plt.axis("off")
# Out:
# (5000, 10000, 3)
# (np.float64(-0.5), np.float64(9999.5), np.float64(4999.5), np.float64(-0.5))
